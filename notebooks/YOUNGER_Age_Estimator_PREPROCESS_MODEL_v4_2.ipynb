# %% [markdown]
# # **YOUNGER - Age Estimator:  Preprocessing & Modeling**
# ---

# %% [markdown]
# ###**Contents**

# %% [markdown]
# [**IV. PREPROCESSING**](#scrollTo=nAuKSR5HuQCy)
#
# * 4.1 Introduction
# * 4.2 Imports
# * 4.3 Load Data
# * 4.4 Transform Data
# * 4.5 Train/Test Split
# * 4.6 Data Augmentation
#
# [**V. MODELING**](#scrollTo=QpXbL0ZoYSpN)
#
# * 5.1 CNN Architecture
# * 5.2 Transfer Learning
# * 5.3 Train the Model
# * 5.4 Model Performance
# * 5.5 Performance Visualization
# * 5.6 Unseen Data Test
#
# [**VI. SUMMARY**](#scrollTo=fRhrsD9SjrO7)
#
#
# [**VII. REFERENCES**](#scrollTo=tD6Lsmxlh3s8)
#
# [**VIII. APPENDIX**](#scrollTo=UhDT3ZLzzWxs)
#
# ---

# %% [markdown]
# # **IV. PREPROCESSING**

# %% [markdown]
# ##**4.1 Introduction**
#
# Previously, to create an age-predictor, we have completed a notebook to import data and explore its attributes: [Data Wrangling & Exploratory Data Analysis](https://github.com/premonish/YOUNGER/blob/main/notebooks/YOUNGER_Age_Estimator_WRANGLING_EDA_v2.ipynb). We took a close look at the metadata and plotted some histograms of the variable distributions. We transformed the data to extract the age of the primary face in each image from their date-of-birth and the date the photo was taken. We focused on extracting a long array of vectors of the pixel information per photo. We finished the previous phase by creating 2 arrays: 'matrix_x' with each row containing the (150,000+ pixel/image) data from each image in the dataset, and 'vector_y' containing the corresponding 'age' labels for the images.
#
# In this notebook, we will focus on Preprocessing & Modeling. In particular, we will use a Convolutional Neural Network, which is industry standard for Machine Learning image classification tasks due to its unmatched performance.
#
#
# ---

# %% [markdown]
# **Class Balance Note:**
# We decided to focus on predicting only the well represented age classes [8-80]. The dataset did not contain enough examples of other ages. Since the dataset had many examples for other ages, we decided to downsample to balance the classes.

# %% [markdown]
# **Historical Context**
# >
# > Image classification has been around for decades, however the field has been rapidly maturing in the last decade.  Since 2010, [ImageNet](https://https://en.wikipedia.org/wiki/ImageNet) Large Scale Visual Recognition Challenge (ILSVRC) is an annual competition where teams attempt to categorize thousands of images into 1,000 classes. In 2012, 'AlexNet' won the competition by a landslide and this is considered a pivotal moment in the history of deep learning, enabled by ingenious data scientists, a massive labeled dataset, and GPUs for training.

# %% [markdown]
# **PREPROCESSING** will be focused on three main sections.
#
# 1. Create Dummy Variables for categorical variables. (One-Hot Encoding)
# 2. Standardize the magnitude of numeric features using a scaler. (Scale 0-1)
# 3. Split data into testing and training datasets.
# ---

# %% [markdown]
# ## **4.2 Imports**

# %%
# !pip install tensorflow

# %%
# Create a list of currently installed python libraries for posterity
# !pip freeze > requirements.txt
# Available here: https://github.com/premonish/YOUNGER/blob/main/requirements2.txt

# %%
### IMPORT libraries and packages ###
### I get by with a little help from my friends ###
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras

# deep-learning imports
from keras.callbacks import ModelCheckpoint,EarlyStopping
from keras.layers import Dense, Activation, Dropout, Flatten, Input, Convolution2D, ZeroPadding2D, MaxPooling2D, Activation
from keras.layers import Conv2D, AveragePooling2D
from keras.models import Model, Sequential
from keras import metrics
from keras.models import model_from_json

# %%
# mount GDrive where the dataset is stored for Colab environment
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## **4.3 Load Data**
# Let's load the compressed numpy arrays from disk, extract data, and check the number of rows in our dataset.

# %%
# %%time
from numpy import asarray, savez_compressed, load
# load dict of arrays
images = np.load('/content/drive/MyDrive/YOUNGER/data5.npz', allow_pickle=True)
matrix_x = images.f.arr_0
X = matrix_x
X.shape
# Out:
# CPU times: user 12.6 s, sys: 2.1 s, total: 14.7 s
# Wall time: 19 s

# %%
# load the ages array 'vector_y'
ages = np.load('/content/drive/MyDrive/YOUNGER/data6.npz', allow_pickle=True)
vector_y = ages.f.arr_0
y = vector_y
y.shape
# Out:
# (5037,)

# %%
# check output matrix_x & vector_y shapes
# both matrix_x and vector_y are arrays of the same length 
assert vector_y.shape == matrix_x.shape

# %% [markdown]
# **NOTE:** I've run many tests to see how many images to include without overwhelming Google Colab's RAM.
#
# I have already upgraded to Colab Pro for this project and have been reaching the RAM limits

# %%
# Plot Age Distribution represented in the dataset
import seaborn as sns
plt.figure(figsize=(5, 3))
sns.histplot(y, color='green')
plt.title('Age Distribution')
plt.xlabel('age')
plt.ylabel('count');

# %% [markdown]
# **^ Notice the balanced classes of the input data achieved in preprocessing.**
#
# We decided to focus on predicting only the well represented age classes [8-80]. The dataset did not contain enough examples of other ages. Since the dataset had many examples for other ages, we decided to downsample to balance the classes.
#
# ---

# %% [markdown]
# ## **4.4 Transform Data**

# %% [markdown]
# **One-Hot Encoding**
#
# We need to encode the 'ages' label as categorical (binary) representations to prepare for machine learning.
# The Keras API provides a 'to_categorical()' method that can be used to one-hot encode integer data.

# %%
# classes = 101   # ages 0 to 100   # We didn't have enough training examples to predict 101 classes
classes = 73      # ages 8 to 80 (inclusive - inclusive)
target = y-8      # prepare for zero-indexed encoding - must add for prediction

# "Converts a class vector (integers) to binary class matrix." 
target_classes = keras.utils.to_categorical(target, classes)

# %% [markdown]
# **Reshaping the Data**
#
# We must reshape the data into the standard input array shape of a 'rank 4 tensor' to prepare for the Tensorflow CNN.
#
# (b, w, h, c) : (batch, width, height, channels)

# %%
features = []
for i in range(0, len(X)):
    features.append(X[i])
features = np.array(features)
features = features.reshape(len(X),224,224,3)
features.shape
# Out:
# (5037, 224, 224, 3)

# %% [markdown]
# **Scale the Data**
#
# Each of the pixel values range from 0-255. Let's scale the values to from 0-1 by dividing each value by 255. Interestingly, we are actually performing this operation virtually instantly 150,528 times per image (times the number of images).

# %%
features /= 255        # scale down pixel values to range [0, 1]
print("The maximum value in our dataset is:", features.max())
# Out:
# The maximum value in our dataset is: 1.0

# %% [markdown]
# ---

# %% [markdown]
# ## **4.5 Train/Test Split**
# We will divide the dataset randomly into training data and test data (80/20). We will later perform data augmentation on only the training set to help balance the classes of ages in the dataset.

# %%
# train/ test split
from sklearn.model_selection import train_test_split
train_x, test_x, train_y, test_y = train_test_split(features, target_classes, test_size=0.30, random_state=42, stratify=target_classes)

# %%
print("X_train shape =" ,train_x.shape) 
print("X_test  shape ="  ,test_x.shape)
print('- - - - - - - - - - - - - - - - - -')
print("y_train shape =" ,train_y.shape)
print("y_test  shape ="  ,test_y.shape)
# Out:
# X_train shape = (3525, 224, 224, 3)
# X_test  shape = (1512, 224, 224, 3)
# - - - - - - - - - - - - - - - - - -
# y_train shape = (3525, 73)
# y_test  shape = (1512, 73)

# %% [markdown]
# Now that we have one-hot encoded the target classes, shaped the input data into tensor-like shapes, scaled the data to 0-1, and split the dataset into training and test subsets, we are ready to move onto modeling.

# %% [markdown]
# ## **4.5 Data Augmentation**
# We will apply some data tranformations to add variation to the training set during when feeding the data into the CNN. We will use random horizontal flipping, random rotations and slight random zooms to increase the diversity of the training data with the intention to reduce overfitting.

# %%
# data augmentation using TensorFlow & Keras to be applied at the start of the CNN
from tensorflow.keras import layers
data_augmentation = keras.Sequential(
  [
    layers.experimental.preprocessing.RandomFlip("horizontal", input_shape=(224,224,3)),
    layers.experimental.preprocessing.RandomRotation(0.1),
    layers.experimental.preprocessing.RandomZoom(0.1),
  ]
)

# %% [markdown]
# ---

# %% [markdown]
# # **V. MODELING**

# %% [markdown]
# **MODELING** will focus on the following four phases.
# 1. Train the models on the dataset (fit)
# 2. Review model performance metrics
# 3. Iterate over other models
# 4. Identify the final model
#
#
# ---

# %% [markdown]
# ## **5.1 CNN Architecture**
#
# I'll start by using an established architecture titled "[VGG-Face](https://www.robots.ox.ac.uk/~vgg/publications/2015/Parkhi15/parkhi15.pdf)" effective for facial recognition and building custom layers on top. This model was created by the Visual Geometry Group, at the University of Oxford to recognize 2,622 celebrities. Facial recognition is a more complex task than age prediction, yet the features extracted from many of the early layers of this model can be useful to our problem.
#
# "These models can be used for non-commercial research purposes under [Creative Commons Attribution License](https://creativecommons.org/licenses/by-nc/4.0/)."
#
# [VGGFace Github](https://github.com/rcmalli/keras-vggface)

# %% [markdown]
# ![vgg_arch.PNG](data:image/png;base64,...)

# %% [markdown]
# **^ VGG-Face Architecture** The first 8 blocks are convolutional. The last 3 blocks are Fully Connected (fc). All convolution layers are followed by a ReLU (recitified linear unit) activation later. A softmax layer predicts probabilities of the labels.

# %%
#VGG-Face model
model = Sequential(data_augmentation)                    # apply data augmentation
model.add(ZeroPadding2D((1,1),input_shape=(224,224, 3)))
model.add(Convolution2D(64, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))
 
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(128, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))
 
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(256, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(256, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(256, (3, 3), activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))
 
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))
 
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation='relu'))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))
 
model.add(Convolution2D(4096, (7, 7), activation='relu'))
model.add(Dropout(0.5))
model.add(Convolution2D(4096, (1, 1), activation='relu'))
model.add(Dropout(0.5))
model.add(Convolution2D(2622, (1, 1)))
model.add(Flatten())
model.add(Activation('softmax'))

# %% [markdown]
# ---

# %% [markdown]
# ## **5.2 Transfer Learning**
#
# Transfer learning allows us to use weights that have already been trained on a massive dataset (2.6M images in this case). For similar tasks, we can simply freeze the weights for many of the early layers. However, the later layers in the model will need to trained and tuned for our specific task.
#
# **Trained weights source:**
# https://www.robots.ox.ac.uk/~vgg/publications/2015/Parkhi15/parkhi15.pdf

# %%
# load the pre-trained weights to take advantage of transfer learning
model.load_weights('/content/drive/MyDrive/YOUNGER/vgg_face_weights.h5')

# %% [markdown]
# **To take advantage of transfer learning, we will freeze layers with trained weights. We will custom tune the last four layers for our age predictor based on our training set.**

# %%
# freeze layers to use transfer learning effectively
for layer in model.layers[:-7]:
  layer.trainable = False

# add custom layers to predict on unique dataset and problem 
base_model_output = Sequential()
base_model_output = Convolution2D(73, (1, 1), name='predictions')(model.layers[-4].output)
base_model_output = Flatten()(base_model_output)
base_model_output = Activation('softmax')(base_model_output)
 
age_model = Model(inputs=model.input, outputs=base_model_output)

# %%
#check trainable layers
if False:
    for layer in model.layers:
        print(layer, layer.trainable)
    
    print("------------------------")
    for layer in age_model.layers:
        print(layer, layer.trainable)

# %% [markdown]
# **Compile Model**
#
# Categorical crossentropy is an appropriate loss function for multi-class classification problems.
#
# We will use an 'Adam' optimizer with a learning rate of 0.0007.

# %%
# Stochastic Gradient Descent = sgd
# compile the model
# sgd = keras.optimizers.SGD(lr=1e-3, decay=1e-6, momentum=.9, nesterov=True)

opt = keras.optimizers.Adam(learning_rate=0.0007,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-07,
    name="Adam"
)

# 'categorical_crossentropy' is an appropriate loss function for a multi-class classification problem such as ours
age_model.compile(loss='categorical_crossentropy'
                  , optimizer = opt
                  # , optimizer = sgd
                  , metrics=['accuracy']
                 )

# %% [markdown]
# **Model Checkpoint**
#
# Validation Loss is our key performance metric. We create a checkpointer which automatically saves the best model based on improved 'val_loss' performance. We can later use the best pre-trained model to measure the performance of the model on unseen data.

# %%
# create checkpoint which saves the best model based on loss on the validation data 
# if the validation loss decreases, the model will be saved as a checkpoint
checkpointer = ModelCheckpoint(
    # filepath='/content/classification_age_model.hdf5'
    filepath='/content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5'
    , monitor = "val_loss"
    , verbose=1
    , save_best_only=True
    , mode = 'min'
    # , mode = 'auto'
)

# %% [markdown]
# **Early Stopping**
#
# Early Stopping will notice when the validation loss is not improving  and it will stop the training to prevent overfitting.

# %%
# enable Early Stopping 
from tensorflow.keras.callbacks import EarlyStopping
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=5)

# %% [markdown]
# **Tensorboard**
#
# Tensorboard allows us to experiment, visualizing changes in model details (hyperparameters) and perfomance metrics.

# %%
#tensorboard
# %load_ext tensorboard
import datetime

# %%
# instantiate TensorBoard and define callback variable
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# %% [markdown]
# **Save Performance Metrics**
#
# Kera's 'History' callback allows us to track performance metrics which we can later visualize.

# %%
# record model performance
from keras.callbacks import History 
history = History()

# %%
# Clear any logs from previous runs - TensorBoard
! rm -rf ./logs/

# %% [markdown]
# ---

# %% [markdown]
# ##**5.3 Train the Model**
#
# Training the model is where the magic happens. We will train our model for a given number of epochs with a given batchsize. We have tried many iterations with various batchsizes and various numbers of epochs to reach allow proper training while avoiding overfitting. Our primary performance metric is validation loss. As the model progresses through epochs, we want the validation loss to decrease at a steady pace.
#
# We will save our best model. In the future, we can simply use the saved model to predict on new data.

# %%
# set batch size and # of epochs
# fit the model on training set & validate on the test set
epochs = 200           # original = 250
batch_size = 128       # original = 256

enableFit = True

if enableFit:
    for i in range(epochs):
        print("epoch ",i)
        ix_train = np.random.choice(train_x.shape[0], size=batch_size)
        
        score = age_model.fit(
            train_x[ix_train], train_y[ix_train],
            epochs=1,
            validation_data=(test_x, test_y),
            callbacks=[tensorboard_callback, checkpointer, callback, history])
        
    #restore the best weights
    from keras.models import load_model
    age_model = load_model('/content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5')
    age_model.save_weights('/content/drive/MyDrive/YOUNGER/age_model_weights_6.h5')
        
else:
    # pre-trained weights for age prediction
    age_model.load_weights("/content/drive/MyDrive/YOUNGER/age_model_weights_6.h5")
# Out:
# epoch  0
# 4/4 [==============================] - 25s 2s/step - loss: 4.2897 - accuracy: 0.0083 - val_loss: 4.2883 - val_accuracy: 0.0159
#
# Epoch 00001: val_loss improved from inf to 4.28832, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  1
# 4/4 [==============================] - 4s 1s/step - loss: 4.3106 - accuracy: 0.0078 - val_loss: 4.3164 - val_accuracy: 0.0179
#
# Epoch 00001: val_loss did not improve from 4.28832
# epoch  2
# 4/4 [==============================] - 4s 1s/step - loss: 4.3372 - accuracy: 0.0312 - val_loss: 4.3179 - val_accuracy: 0.0231
#
# Epoch 00001: val_loss did not improve from 4.28832
# epoch  3
# 4/4 [==============================] - 4s 1s/step - loss: 4.3024 - accuracy: 0.0234 - val_loss: 4.3422 - val_accuracy: 0.0139
#
# Epoch 00001: val_loss did not improve from 4.28832
# epoch  4
# 4/4 [==============================] - 4s 1s/step - loss: 4.3266 - accuracy: 0.0312 - val_loss: 4.3280 - val_accuracy: 0.0132
#
# Epoch 00001: val_loss did not improve from 4.28832
# epoch  5
# 4/4 [==============================] - 4s 1s/step - loss: 4.3599 - accuracy: 0.0391 - val_loss: 4.2989 - val_accuracy: 0.0132
#
# Epoch 00001: val_loss did not improve from 4.28832
# epoch  6
# 4/4 [==============================] - 4s 1s/step - loss: 4.2635 - accuracy: 0.0156 - val_loss: 4.2910 - val_accuracy: 0.0245
#
# Epoch 00001: val_loss did not improve from 4.28832
# epoch  7
# 4/4 [==============================] - 4s 1s/step - loss: 4.2819 - accuracy: 0.0156 - val_loss: 4.2851 - val_accuracy: 0.0265
#
# Epoch 00001: val_loss improved from 4.28832 to 4.28509, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  8
# 4/4 [==============================] - 4s 1s/step - loss: 4.2580 - accuracy: 0.0312 - val_loss: 4.2760 - val_accuracy: 0.0258
#
# Epoch 00001: val_loss improved from 4.28509 to 4.27598, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  9
# 4/4 [==============================] - 4s 1s/step - loss: 4.2573 - accuracy: 0.0156 - val_loss: 4.2619 - val_accuracy: 0.0225
#
# Epoch 00001: val_loss improved from 4.27598 to 4.26188, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  10
# 4/4 [==============================] - 4s 1s/step - loss: 4.2263 - accuracy: 0.0156 - val_loss: 4.2442 - val_accuracy: 0.0238
#
# Epoch 00001: val_loss improved from 4.26188 to 4.24416, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  11
# 4/4 [==============================] - 4s 1s/step - loss: 4.2451 - accuracy: 0.0156 - val_loss: 4.2140 - val_accuracy: 0.0225
#
# Epoch 00001: val_loss improved from 4.24416 to 4.21401, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  12
# 4/4 [==============================] - 4s 1s/step - loss: 4.2697 - accuracy: 0.0078 - val_loss: 4.1794 - val_accuracy: 0.0304
#
# Epoch 00001: val_loss improved from 4.21401 to 4.17939, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  13
# 4/4 [==============================] - 4s 1s/step - loss: 4.1925 - accuracy: 0.0312 - val_loss: 4.1456 - val_accuracy: 0.0311
#
# Epoch 00001: val_loss improved from 4.17939 to 4.14560, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  14
# 4/4 [==============================] - 4s 1s/step - loss: 4.1292 - accuracy: 0.0156 - val_loss: 4.1014 - val_accuracy: 0.0291
#
# Epoch 00001: val_loss improved from 4.14560 to 4.10140, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  15
# 4/4 [==============================] - 4s 1s/step - loss: 4.1342 - accuracy: 0.0312 - val_loss: 4.0678 - val_accuracy: 0.0298
#
# Epoch 00001: val_loss improved from 4.10140 to 4.06781, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  16
# 4/4 [==============================] - 4s 1s/step - loss: 4.1174 - accuracy: 0.0391 - val_loss: 4.0368 - val_accuracy: 0.0304
#
# Epoch 00001: val_loss improved from 4.06781 to 4.03683, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  17
# 4/4 [==============================] - 4s 1s/step - loss: 4.1038 - accuracy: 0.0312 - val_loss: 4.0000 - val_accuracy: 0.0265
#
# Epoch 00001: val_loss improved from 4.03683 to 3.99999, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  18
# 4/4 [==============================] - 4s 1s/step - loss: 3.9973 - accuracy: 0.0156 - val_loss: 3.9961 - val_accuracy: 0.0317
#
# Epoch 00001: val_loss improved from 3.99999 to 3.99611, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  19
# 4/4 [==============================] - 4s 1s/step - loss: 4.0166 - accuracy: 0.0078 - val_loss: 4.0148 - val_accuracy: 0.0291
#
# Epoch 00001: val_loss did not improve from 3.99611
# epoch  20
# 4/4 [==============================] - 4s 1s/step - loss: 4.0896 - accuracy: 0.0078 - val_loss: 4.0000 - val_accuracy: 0.0278
#
# Epoch 00001: val_loss did not improve from 3.99611
# epoch  21
# 4/4 [==============================] - 4s 1s/step - loss: 3.9794 - accuracy: 0.0391 - val_loss: 3.9775 - val_accuracy: 0.0238
#
# Epoch 00001: val_loss improved from 3.99611 to 3.97747, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  22
# 4/4 [==============================] - 4s 1s/step - loss: 3.9823 - accuracy: 0.0391 - val_loss: 3.9361 - val_accuracy: 0.0265
#
# Epoch 00001: val_loss improved from 3.97747 to 3.93614, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  23
# 4/4 [==============================] - 4s 1s/step - loss: 3.9001 - accuracy: 0.0547 - val_loss: 3.9517 - val_accuracy: 0.0324
#
# Epoch 00001: val_loss did not improve from 3.93614
# epoch  24
# 4/4 [==============================] - 4s 1s/step - loss: 3.9609 - accuracy: 0.0391 - val_loss: 3.8938 - val_accuracy: 0.0364
#
# Epoch 00001: val_loss improved from 3.93614 to 3.89384, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  25
# 4/4 [==============================] - 4s 1s/step - loss: 3.9279 - accuracy: 0.0469 - val_loss: 3.8891 - val_accuracy: 0.0390
#
# Epoch 00001: val_loss improved from 3.89384 to 3.88910, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  26
# 4/4 [==============================] - 4s 1s/step - loss: 3.9092 - accuracy: 0.0391 - val_loss: 3.8711 - val_accuracy: 0.0430
#
# Epoch 00001: val_loss improved from 3.88910 to 3.87110, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  27
# 4/4 [==============================] - 4s 1s/step - loss: 3.9951 - accuracy: 0.0312 - val_loss: 3.8634 - val_accuracy: 0.0337
#
# Epoch 00001: val_loss improved from 3.87110 to 3.86343, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  28
# 4/4 [==============================] - 4s 1s/step - loss: 3.8909 - accuracy: 0.0781 - val_loss: 3.8543 - val_accuracy: 0.0430
#
# Epoch 00001: val_loss improved from 3.86343 to 3.85429, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  29
# 4/4 [==============================] - 4s 1s/step - loss: 4.0291 - accuracy: 0.0234 - val_loss: 3.8989 - val_accuracy: 0.0417
#
# Epoch 00001: val_loss did not improve from 3.85429
# epoch  30
# 4/4 [==============================] - 4s 1s/step - loss: 3.9071 - accuracy: 0.0234 - val_loss: 3.8695 - val_accuracy: 0.0384
#
# Epoch 00001: val_loss did not improve from 3.85429
# epoch  31
# 4/4 [==============================] - 4s 1s/step - loss: 3.9451 - accuracy: 0.0312 - val_loss: 3.8372 - val_accuracy: 0.0410
#
# Epoch 00001: val_loss improved from 3.85429 to 3.83720, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  32
# 4/4 [==============================] - 4s 1s/step - loss: 3.9247 - accuracy: 0.0234 - val_loss: 3.8155 - val_accuracy: 0.0417
#
# Epoch 00001: val_loss improved from 3.83720 to 3.81546, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  33
# 4/4 [==============================] - 4s 1s/step - loss: 3.6775 - accuracy: 0.0859 - val_loss: 3.8113 - val_accuracy: 0.0423
#
# Epoch 00001: val_loss improved from 3.81546 to 3.81129, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  34
# 4/4 [==============================] - 4s 1s/step - loss: 3.8863 - accuracy: 0.0469 - val_loss: 3.8550 - val_accuracy: 0.0384
#
# Epoch 00001: val_loss did not improve from 3.81129
# epoch  35
# 4/4 [==============================] - 4s 1s/step - loss: 3.8202 - accuracy: 0.0234 - val_loss: 3.7822 - val_accuracy: 0.0463
#
# Epoch 00001: val_loss improved from 3.81129 to 3.78221, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  36
# 4/4 [==============================] - 4s 1s/step - loss: 3.8263 - accuracy: 0.0312 - val_loss: 3.7689 - val_accuracy: 0.0456
#
# Epoch 00001: val_loss improved from 3.78221 to 3.76886, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  37
# 4/4 [==============================] - 4s 1s/step - loss: 3.9160 - accuracy: 0.0703 - val_loss: 3.7591 - val_accuracy: 0.0443
#
# Epoch 00001: val_loss improved from 3.76886 to 3.75915, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  38
# 4/4 [==============================] - 4s 1s/step - loss: 3.8280 - accuracy: 0.0469 - val_loss: 3.7369 - val_accuracy: 0.0569
#
# Epoch 00001: val_loss improved from 3.75915 to 3.73687, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  39
# 4/4 [==============================] - 4s 1s/step - loss: 3.6998 - accuracy: 0.0547 - val_loss: 3.7624 - val_accuracy: 0.0450
#
# Epoch 00001: val_loss did not improve from 3.73687
# epoch  40
# 4/4 [==============================] - 4s 1s/step - loss: 3.8031 - accuracy: 0.0312 - val_loss: 3.7729 - val_accuracy: 0.0450
#
# Epoch 00001: val_loss did not improve from 3.73687
# epoch  41
# 4/4 [==============================] - 4s 1s/step - loss: 3.8255 - accuracy: 0.0391 - val_loss: 3.7636 - val_accuracy: 0.0430
#
# Epoch 00001: val_loss did not improve from 3.73687
# epoch  42
# 4/4 [==============================] - 4s 1s/step - loss: 3.9289 - accuracy: 0.0625 - val_loss: 3.7639 - val_accuracy: 0.0377
#
# Epoch 00001: val_loss did not improve from 3.73687
# epoch  43
# 4/4 [==============================] - 4s 1s/step - loss: 3.7010 - accuracy: 0.0469 - val_loss: 3.7301 - val_accuracy: 0.0450
#
# Epoch 00001: val_loss improved from 3.73687 to 3.73009, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  44
# 4/4 [==============================] - 4s 1s/step - loss: 3.8486 - accuracy: 0.0391 - val_loss: 3.7578 - val_accuracy: 0.0317
#
# Epoch 00001: val_loss did not improve from 3.73009
# epoch  45
# 4/4 [==============================] - 4s 1s/step - loss: 3.8089 - accuracy: 0.0234 - val_loss: 3.7193 - val_accuracy: 0.0370
#
# Epoch 00001: val_loss improved from 3.73009 to 3.71927, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  46
# 4/4 [==============================] - 4s 1s/step - loss: 3.8215 - accuracy: 0.0312 - val_loss: 3.7434 - val_accuracy: 0.0430
#
# Epoch 00001: val_loss did not improve from 3.71927
# epoch  47
# 4/4 [==============================] - 4s 1s/step - loss: 3.6953 - accuracy: 0.0391 - val_loss: 3.7056 - val_accuracy: 0.0483
#
# Epoch 00001: val_loss improved from 3.71927 to 3.70565, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  48
# 4/4 [==============================] - 4s 1s/step - loss: 3.7933 - accuracy: 0.0781 - val_loss: 3.6822 - val_accuracy: 0.0423
#
# Epoch 00001: val_loss improved from 3.70565 to 3.68222, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  49
# 4/4 [==============================] - 4s 1s/step - loss: 3.6646 - accuracy: 0.0547 - val_loss: 3.7107 - val_accuracy: 0.0450
#
# Epoch 00001: val_loss did not improve from 3.68222
# epoch  50
# 4/4 [==============================] - 4s 1s/step - loss: 3.6912 - accuracy: 0.0547 - val_loss: 3.6941 - val_accuracy: 0.0556
#
# Epoch 00001: val_loss did not improve from 3.68222
# epoch  51
# 4/4 [==============================] - 4s 1s/step - loss: 3.7524 - accuracy: 0.0391 - val_loss: 3.6994 - val_accuracy: 0.0522
#
# Epoch 00001: val_loss did not improve from 3.68222
# epoch  52
# 4/4 [==============================] - 4s 1s/step - loss: 3.7730 - accuracy: 0.0234 - val_loss: 3.7037 - val_accuracy: 0.0529
#
# Epoch 00001: val_loss did not improve from 3.68222
# epoch  53
# 4/4 [==============================] - 4s 1s/step - loss: 3.6673 - accuracy: 0.0547 - val_loss: 3.7023 - val_accuracy: 0.0503
#
# Epoch 00001: val_loss did not improve from 3.68222
# epoch  54
# 4/4 [==============================] - 4s 1s/step - loss: 3.7572 - accuracy: 0.0391 - val_loss: 3.6656 - val_accuracy: 0.0463
#
# Epoch 00001: val_loss improved from 3.68222 to 3.66564, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  55
# 4/4 [==============================] - 4s 1s/step - loss: 3.6906 - accuracy: 0.0469 - val_loss: 3.6904 - val_accuracy: 0.0450
#
# Epoch 00001: val_loss did not improve from 3.66564
# epoch  56
# 4/4 [==============================] - 4s 1s/step - loss: 3.7014 - accuracy: 0.0703 - val_loss: 3.6672 - val_accuracy: 0.0437
#
# Epoch 00001: val_loss did not improve from 3.66564
# epoch  57
# 4/4 [==============================] - 4s 1s/step - loss: 3.6324 - accuracy: 0.0547 - val_loss: 3.6687 - val_accuracy: 0.0443
#
# Epoch 00001: val_loss did not improve from 3.66564
# epoch  58
# 4/4 [==============================] - 4s 1s/step - loss: 3.7731 - accuracy: 0.0547 - val_loss: 3.6721 - val_accuracy: 0.0430
#
# Epoch 00001: val_loss did not improve from 3.66564
# epoch  59
# 4/4 [==============================] - 4s 1s/step - loss: 3.6912 - accuracy: 0.0469 - val_loss: 3.6854 - val_accuracy: 0.0562
#
# Epoch 00001: val_loss did not improve from 3.66564
# epoch  60
# 4/4 [==============================] - 4s 1s/step - loss: 3.6575 - accuracy: 0.0781 - val_loss: 3.6772 - val_accuracy: 0.0522
#
# Epoch 00001: val_loss did not improve from 3.66564
# epoch  61
# 4/4 [==============================] - 4s 1s/step - loss: 3.7220 - accuracy: 0.0703 - val_loss: 3.6833 - val_accuracy: 0.0536
#
# Epoch 00001: val_loss did not improve from 3.66564
# epoch  62
# 4/4 [==============================] - 4s 1s/step - loss: 3.6460 - accuracy: 0.0547 - val_loss: 3.7075 - val_accuracy: 0.0602
#
# Epoch 00001: val_loss did not improve from 3.66564
# epoch  63
# 4/4 [==============================] - 4s 1s/step - loss: 3.6060 - accuracy: 0.0938 - val_loss: 3.6853 - val_accuracy: 0.0556
#
# Epoch 00001: val_loss did not improve from 3.66564
# epoch  64
# 4/4 [==============================] - 4s 1s/step - loss: 3.6526 - accuracy: 0.0703 - val_loss: 3.6696 - val_accuracy: 0.0542
#
# Epoch 00001: val_loss did not improve from 3.66564
# epoch  65
# 4/4 [==============================] - 4s 1s/step - loss: 3.6922 - accuracy: 0.0625 - val_loss: 3.6628 - val_accuracy: 0.0582
#
# Epoch 00001: val_loss improved from 3.66564 to 3.66279, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  66
# 4/4 [==============================] - 4s 1s/step - loss: 3.8325 - accuracy: 0.0391 - val_loss: 3.6662 - val_accuracy: 0.0589
#
# Epoch 00001: val_loss did not improve from 3.66279
# epoch  67
# 4/4 [==============================] - 4s 1s/step - loss: 3.6661 - accuracy: 0.0625 - val_loss: 3.6688 - val_accuracy: 0.0470
#
# Epoch 00001: val_loss did not improve from 3.66279
# epoch  68
# 4/4 [==============================] - 4s 1s/step - loss: 3.6307 - accuracy: 0.0703 - val_loss: 3.6664 - val_accuracy: 0.0496
#
# Epoch 00001: val_loss did not improve from 3.66279
# epoch  69
# 4/4 [==============================] - 4s 1s/step - loss: 3.6308 - accuracy: 0.0703 - val_loss: 3.6697 - val_accuracy: 0.0536
#
# Epoch 00001: val_loss did not improve from 3.66279
# epoch  70
# 4/4 [==============================] - 4s 1s/step - loss: 3.6470 - accuracy: 0.0469 - val_loss: 3.6685 - val_accuracy: 0.0542
#
# Epoch 00001: val_loss did not improve from 3.66279
# epoch  71
# 4/4 [==============================] - 4s 1s/step - loss: 3.6563 - accuracy: 0.0781 - val_loss: 3.6555 - val_accuracy: 0.0476
#
# Epoch 00001: val_loss improved from 3.66279 to 3.65554, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  72
# 4/4 [==============================] - 4s 1s/step - loss: 3.6905 - accuracy: 0.0469 - val_loss: 3.6711 - val_accuracy: 0.0476
#
# Epoch 00001: val_loss did not improve from 3.65554
# epoch  73
# 4/4 [==============================] - 4s 1s/step - loss: 3.7029 - accuracy: 0.0469 - val_loss: 3.6610 - val_accuracy: 0.0503
#
# Epoch 00001: val_loss did not improve from 3.65554
# epoch  74
# 4/4 [==============================] - 4s 1s/step - loss: 3.6331 - accuracy: 0.0781 - val_loss: 3.6365 - val_accuracy: 0.0483
#
# Epoch 00001: val_loss improved from 3.65554 to 3.63646, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  75
# 4/4 [==============================] - 4s 1s/step - loss: 3.6277 - accuracy: 0.0781 - val_loss: 3.6493 - val_accuracy: 0.0549
#
# Epoch 00001: val_loss did not improve from 3.63646
# epoch  76
# 4/4 [==============================] - 4s 1s/step - loss: 3.6914 - accuracy: 0.0703 - val_loss: 3.6439 - val_accuracy: 0.0556
#
# Epoch 00001: val_loss did not improve from 3.63646
# epoch  77
# 4/4 [==============================] - 4s 1s/step - loss: 3.5704 - accuracy: 0.0859 - val_loss: 3.6299 - val_accuracy: 0.0549
#
# Epoch 00001: val_loss improved from 3.63646 to 3.62994, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  78
# 4/4 [==============================] - 4s 1s/step - loss: 3.6079 - accuracy: 0.0547 - val_loss: 3.6564 - val_accuracy: 0.0582
#
# Epoch 00001: val_loss did not improve from 3.62994
# epoch  79
# 4/4 [==============================] - 4s 1s/step - loss: 3.5401 - accuracy: 0.0469 - val_loss: 3.6653 - val_accuracy: 0.0503
#
# Epoch 00001: val_loss did not improve from 3.62994
# epoch  80
# 4/4 [==============================] - 4s 1s/step - loss: 3.6363 - accuracy: 0.0625 - val_loss: 3.6824 - val_accuracy: 0.0456
#
# Epoch 00001: val_loss did not improve from 3.62994
# epoch  81
# 4/4 [==============================] - 4s 1s/step - loss: 3.5732 - accuracy: 0.0859 - val_loss: 3.6409 - val_accuracy: 0.0549
#
# Epoch 00001: val_loss did not improve from 3.62994
# epoch  82
# 4/4 [==============================] - 4s 1s/step - loss: 3.6642 - accuracy: 0.0938 - val_loss: 3.6610 - val_accuracy: 0.0582
#
# Epoch 00001: val_loss did not improve from 3.62994
# epoch  83
# 4/4 [==============================] - 4s 1s/step - loss: 3.7538 - accuracy: 0.0391 - val_loss: 3.6551 - val_accuracy: 0.0582
#
# Epoch 00001: val_loss did not improve from 3.62994
# epoch  84
# 4/4 [==============================] - 4s 1s/step - loss: 3.6931 - accuracy: 0.0781 - val_loss: 3.6541 - val_accuracy: 0.0602
#
# Epoch 00001: val_loss did not improve from 3.62994
# epoch  85
# 4/4 [==============================] - 4s 1s/step - loss: 3.4917 - accuracy: 0.1016 - val_loss: 3.6352 - val_accuracy: 0.0549
#
# Epoch 00001: val_loss did not improve from 3.62994
# epoch  86
# 4/4 [==============================] - 4s 1s/step - loss: 3.6556 - accuracy: 0.0469 - val_loss: 3.6309 - val_accuracy: 0.0562
#
# Epoch 00001: val_loss did not improve from 3.62994
# epoch  87
# 4/4 [==============================] - 4s 1s/step - loss: 3.6657 - accuracy: 0.0703 - val_loss: 3.6199 - val_accuracy: 0.0556
#
# Epoch 00001: val_loss improved from 3.62994 to 3.61990, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  88
# 4/4 [==============================] - 4s 1s/step - loss: 3.6301 - accuracy: 0.0938 - val_loss: 3.6256 - val_accuracy: 0.0562
#
# Epoch 00001: val_loss did not improve from 3.61990
# epoch  89
# 4/4 [==============================] - 4s 1s/step - loss: 3.5296 - accuracy: 0.0547 - val_loss: 3.6526 - val_accuracy: 0.0575
#
# Epoch 00001: val_loss did not improve from 3.61990
# epoch  90
# 4/4 [==============================] - 4s 1s/step - loss: 3.5924 - accuracy: 0.1250 - val_loss: 3.6539 - val_accuracy: 0.0575
#
# Epoch 00001: val_loss did not improve from 3.61990
# epoch  91
# 4/4 [==============================] - 4s 1s/step - loss: 3.6821 - accuracy: 0.0625 - val_loss: 3.6571 - val_accuracy: 0.0569
#
# Epoch 00001: val_loss did not improve from 3.61990
# epoch  92
# 4/4 [==============================] - 4s 1s/step - loss: 3.5660 - accuracy: 0.0781 - val_loss: 3.6865 - val_accuracy: 0.0608
#
# Epoch 00001: val_loss did not improve from 3.61990
# epoch  93
# 4/4 [==============================] - 4s 1s/step - loss: 3.5557 - accuracy: 0.0625 - val_loss: 3.6552 - val_accuracy: 0.0668
#
# Epoch 00001: val_loss did not improve from 3.61990
# epoch  94
# 4/4 [==============================] - 4s 1s/step - loss: 3.4984 - accuracy: 0.0938 - val_loss: 3.6478 - val_accuracy: 0.0642
#
# Epoch 00001: val_loss did not improve from 3.61990
# epoch  95
# 4/4 [==============================] - 4s 1s/step - loss: 3.6280 - accuracy: 0.0859 - val_loss: 3.6360 - val_accuracy: 0.0622
#
# Epoch 00001: val_loss did not improve from 3.61990
# epoch  96
# 4/4 [==============================] - 4s 1s/step - loss: 3.5078 - accuracy: 0.1094 - val_loss: 3.6313 - val_accuracy: 0.0648
#
# Epoch 00001: val_loss did not improve from 3.61990
# epoch  97
# 4/4 [==============================] - 4s 1s/step - loss: 3.6175 - accuracy: 0.0859 - val_loss: 3.6198 - val_accuracy: 0.0608
#
# Epoch 00001: val_loss improved from 3.61990 to 3.61982, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  98
# 4/4 [==============================] - 4s 1s/step - loss: 3.5100 - accuracy: 0.0781 - val_loss: 3.6255 - val_accuracy: 0.0701
#
# Epoch 00001: val_loss did not improve from 3.61982
# epoch  99
# 4/4 [==============================] - 4s 1s/step - loss: 3.5875 - accuracy: 0.0859 - val_loss: 3.6316 - val_accuracy: 0.0648
#
# Epoch 00001: val_loss did not improve from 3.61982
# epoch  100
# 4/4 [==============================] - 4s 1s/step - loss: 3.6115 - accuracy: 0.0781 - val_loss: 3.6189 - val_accuracy: 0.0542
#
# Epoch 00001: val_loss improved from 3.61982 to 3.61890, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  101
# 4/4 [==============================] - 4s 1s/step - loss: 3.6380 - accuracy: 0.0781 - val_loss: 3.6327 - val_accuracy: 0.0575
#
# Epoch 00001: val_loss did not improve from 3.61890
# epoch  102
# 4/4 [==============================] - 4s 1s/step - loss: 3.6364 - accuracy: 0.0781 - val_loss: 3.6363 - val_accuracy: 0.0628
#
# Epoch 00001: val_loss did not improve from 3.61890
# epoch  103
# 4/4 [==============================] - 4s 1s/step - loss: 3.4705 - accuracy: 0.1094 - val_loss: 3.6134 - val_accuracy: 0.0582
#
# Epoch 00001: val_loss improved from 3.61890 to 3.61339, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  104
# 4/4 [==============================] - 4s 1s/step - loss: 3.5657 - accuracy: 0.1250 - val_loss: 3.6111 - val_accuracy: 0.0575
#
# Epoch 00001: val_loss improved from 3.61339 to 3.61114, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  105
# 4/4 [==============================] - 4s 1s/step - loss: 3.5550 - accuracy: 0.0938 - val_loss: 3.6288 - val_accuracy: 0.0661
#
# Epoch 00001: val_loss did not improve from 3.61114
# epoch  106
# 4/4 [==============================] - 4s 1s/step - loss: 3.4842 - accuracy: 0.1172 - val_loss: 3.6490 - val_accuracy: 0.0582
#
# Epoch 00001: val_loss did not improve from 3.61114
# epoch  107
# 4/4 [==============================] - 4s 1s/step - loss: 3.4821 - accuracy: 0.1016 - val_loss: 3.7083 - val_accuracy: 0.0542
#
# Epoch 00001: val_loss did not improve from 3.61114
# epoch  108
# 4/4 [==============================] - 4s 1s/step - loss: 3.5784 - accuracy: 0.1016 - val_loss: 3.6797 - val_accuracy: 0.0542
#
# Epoch 00001: val_loss did not improve from 3.61114
# epoch  109
# 4/4 [==============================] - 4s 1s/step - loss: 3.6371 - accuracy: 0.0703 - val_loss: 3.6932 - val_accuracy: 0.0595
#
# Epoch 00001: val_loss did not improve from 3.61114
# epoch  110
# 4/4 [==============================] - 4s 1s/step - loss: 3.7209 - accuracy: 0.0703 - val_loss: 3.6420 - val_accuracy: 0.0595
#
# Epoch 00001: val_loss did not improve from 3.61114
# epoch  111
# 4/4 [==============================] - 4s 1s/step - loss: 3.6584 - accuracy: 0.0547 - val_loss: 3.6298 - val_accuracy: 0.0556
#
# Epoch 00001: val_loss did not improve from 3.61114
# epoch  112
# 4/4 [==============================] - 4s 1s/step - loss: 3.5441 - accuracy: 0.0547 - val_loss: 3.6464 - val_accuracy: 0.0562
#
# Epoch 00001: val_loss did not improve from 3.61114
# epoch  113
# 4/4 [==============================] - 4s 1s/step - loss: 3.3931 - accuracy: 0.0781 - val_loss: 3.6304 - val_accuracy: 0.0556
#
# Epoch 00001: val_loss did not improve from 3.61114
# epoch  114
# 4/4 [==============================] - 4s 1s/step - loss: 3.5036 - accuracy: 0.1016 - val_loss: 3.6770 - val_accuracy: 0.0562
#
# Epoch 00001: val_loss did not improve from 3.61114
# epoch  115
# 4/4 [==============================] - 4s 1s/step - loss: 3.4683 - accuracy: 0.1328 - val_loss: 3.6662 - val_accuracy: 0.0509
#
# Epoch 00001: val_loss did not improve from 3.61114
# epoch  116
# 4/4 [==============================] - 4s 1s/step - loss: 3.4777 - accuracy: 0.0547 - val_loss: 3.6761 - val_accuracy: 0.0522
#
# Epoch 00001: val_loss did not improve from 3.61114
# epoch  117
# 4/4 [==============================] - 4s 1s/step - loss: 3.5544 - accuracy: 0.1016 - val_loss: 3.6406 - val_accuracy: 0.0582
#
# Epoch 00001: val_loss did not improve from 3.61114
# epoch  118
# 4/4 [==============================] - 4s 1s/step - loss: 3.5251 - accuracy: 0.1250 - val_loss: 3.6270 - val_accuracy: 0.0615
#
# Epoch 00001: val_loss did not improve from 3.61114
# epoch  119
# 4/4 [==============================] - 4s 1s/step - loss: 3.4788 - accuracy: 0.0625 - val_loss: 3.6349 - val_accuracy: 0.0648
#
# Epoch 00001: val_loss did not improve from 3.61114
# epoch  120
# 4/4 [==============================] - 4s 1s/step - loss: 3.5582 - accuracy: 0.0781 - val_loss: 3.6412 - val_accuracy: 0.0648
#
# Epoch 00001: val_loss did not improve from 3.61114
# epoch  121
# 4/4 [==============================] - 4s 1s/step - loss: 3.5037 - accuracy: 0.1094 - val_loss: 3.6718 - val_accuracy: 0.0635
#
# Epoch 00001: val_loss did not improve from 3.61114
# epoch  122
# 4/4 [==============================] - 4s 1s/step - loss: 3.4274 - accuracy: 0.1250 - val_loss: 3.6778 - val_accuracy: 0.0602
#
# Epoch 00001: val_loss did not improve from 3.61114
# epoch  123
# 4/4 [==============================] - 4s 1s/step - loss: 3.4614 - accuracy: 0.0625 - val_loss: 3.6398 - val_accuracy: 0.0622
#
# Epoch 00001: val_loss did not improve from 3.61114
# epoch  124
# 4/4 [==============================] - 4s 1s/step - loss: 3.4889 - accuracy: 0.0781 - val_loss: 3.6302 - val_accuracy: 0.0688
#
# Epoch 00001: val_loss did not improve from 3.61114
# epoch  125
# 4/4 [==============================] - 4s 1s/step - loss: 3.5484 - accuracy: 0.1094 - val_loss: 3.6081 - val_accuracy: 0.0721
#
# Epoch 00001: val_loss improved from 3.61114 to 3.60809, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  126
# 4/4 [==============================] - 4s 1s/step - loss: 3.5592 - accuracy: 0.1406 - val_loss: 3.6398 - val_accuracy: 0.0675
#
# Epoch 00001: val_loss did not improve from 3.60809
# epoch  127
# 4/4 [==============================] - 4s 1s/step - loss: 3.4918 - accuracy: 0.1016 - val_loss: 3.6413 - val_accuracy: 0.0708
#
# Epoch 00001: val_loss did not improve from 3.60809
# epoch  128
# 4/4 [==============================] - 4s 1s/step - loss: 3.4941 - accuracy: 0.1406 - val_loss: 3.6573 - val_accuracy: 0.0675
#
# Epoch 00001: val_loss did not improve from 3.60809
# epoch  129
# 4/4 [==============================] - 4s 1s/step - loss: 3.5287 - accuracy: 0.1016 - val_loss: 3.6628 - val_accuracy: 0.0668
#
# Epoch 00001: val_loss did not improve from 3.60809
# epoch  130
# 4/4 [==============================] - 4s 1s/step - loss: 3.4419 - accuracy: 0.1172 - val_loss: 3.6434 - val_accuracy: 0.0648
#
# Epoch 00001: val_loss did not improve from 3.60809
# epoch  131
# 4/4 [==============================] - 4s 1s/step - loss: 3.5404 - accuracy: 0.0703 - val_loss: 3.6191 - val_accuracy: 0.0661
#
# Epoch 00001: val_loss did not improve from 3.60809
# epoch  132
# 4/4 [==============================] - 4s 1s/step - loss: 3.4424 - accuracy: 0.0781 - val_loss: 3.6237 - val_accuracy: 0.0655
#
# Epoch 00001: val_loss did not improve from 3.60809
# epoch  133
# 4/4 [==============================] - 4s 1s/step - loss: 3.3133 - accuracy: 0.1094 - val_loss: 3.6377 - val_accuracy: 0.0675
#
# Epoch 00001: val_loss did not improve from 3.60809
# epoch  134
# 4/4 [==============================] - 4s 1s/step - loss: 3.5426 - accuracy: 0.1250 - val_loss: 3.6303 - val_accuracy: 0.0675
#
# Epoch 00001: val_loss did not improve from 3.60809
# epoch  135
# 4/4 [==============================] - 4s 1s/step - loss: 3.4271 - accuracy: 0.0625 - val_loss: 3.6392 - val_accuracy: 0.0615
#
# Epoch 00001: val_loss did not improve from 3.60809
# epoch  136
# 4/4 [==============================] - 4s 1s/step - loss: 3.5114 - accuracy: 0.1172 - val_loss: 3.6377 - val_accuracy: 0.0635
#
# Epoch 00001: val_loss did not improve from 3.60809
# epoch  137
# 4/4 [==============================] - 4s 1s/step - loss: 3.5140 - accuracy: 0.0938 - val_loss: 3.6407 - val_accuracy: 0.0642
#
# Epoch 00001: val_loss did not improve from 3.60809
# epoch  138
# 4/4 [==============================] - 4s 1s/step - loss: 3.4081 - accuracy: 0.1016 - val_loss: 3.6395 - val_accuracy: 0.0655
#
# Epoch 00001: val_loss did not improve from 3.60809
# epoch  139
# 4/4 [==============================] - 4s 1s/step - loss: 3.5338 - accuracy: 0.0938 - val_loss: 3.6211 - val_accuracy: 0.0628
#
# Epoch 00001: val_loss did not improve from 3.60809
# epoch  140
# 4/4 [==============================] - 4s 1s/step - loss: 3.5200 - accuracy: 0.1016 - val_loss: 3.6043 - val_accuracy: 0.0569
#
# Epoch 00001: val_loss improved from 3.60809 to 3.60429, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  141
# 4/4 [==============================] - 4s 1s/step - loss: 3.3801 - accuracy: 0.1172 - val_loss: 3.5990 - val_accuracy: 0.0681
#
# Epoch 00001: val_loss improved from 3.60429 to 3.59900, saving model to /content/drive/MyDrive/YOUNGER/classification_age_model_6.hdf5
# epoch  142
# 4/4 [==============================] - 4s 1s/step - loss: 3.3171 - accuracy: 0.1016 - val_loss: 3.6125 - val_accuracy: 0.0708
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  143
# 4/4 [==============================] - 4s 1s/step - loss: 3.4900 - accuracy: 0.1250 - val_loss: 3.6380 - val_accuracy: 0.0681
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  144
# 4/4 [==============================] - 4s 1s/step - loss: 3.5791 - accuracy: 0.0859 - val_loss: 3.6467 - val_accuracy: 0.0734
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  145
# 4/4 [==============================] - 4s 1s/step - loss: 3.3763 - accuracy: 0.1094 - val_loss: 3.6523 - val_accuracy: 0.0708
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  146
# 4/4 [==============================] - 4s 1s/step - loss: 3.5229 - accuracy: 0.0859 - val_loss: 3.6691 - val_accuracy: 0.0628
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  147
# 4/4 [==============================] - 4s 1s/step - loss: 3.4389 - accuracy: 0.1406 - val_loss: 3.6432 - val_accuracy: 0.0569
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  148
# 4/4 [==============================] - 4s 1s/step - loss: 3.4755 - accuracy: 0.0859 - val_loss: 3.6174 - val_accuracy: 0.0549
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  149
# 4/4 [==============================] - 4s 1s/step - loss: 3.3170 - accuracy: 0.1406 - val_loss: 3.6151 - val_accuracy: 0.0608
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  150
# 4/4 [==============================] - 4s 1s/step - loss: 3.3994 - accuracy: 0.1094 - val_loss: 3.6318 - val_accuracy: 0.0642
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  151
# 4/4 [==============================] - 4s 1s/step - loss: 3.2864 - accuracy: 0.1641 - val_loss: 3.6230 - val_accuracy: 0.0628
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  152
# 4/4 [==============================] - 4s 1s/step - loss: 3.3743 - accuracy: 0.1250 - val_loss: 3.6178 - val_accuracy: 0.0628
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  153
# 4/4 [==============================] - 4s 1s/step - loss: 3.2138 - accuracy: 0.1250 - val_loss: 3.6606 - val_accuracy: 0.0622
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  154
# 4/4 [==============================] - 4s 1s/step - loss: 3.2865 - accuracy: 0.1641 - val_loss: 3.6730 - val_accuracy: 0.0694
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  155
# 4/4 [==============================] - 4s 1s/step - loss: 3.4229 - accuracy: 0.0938 - val_loss: 3.6882 - val_accuracy: 0.0635
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  156
# 4/4 [==============================] - 4s 1s/step - loss: 3.5696 - accuracy: 0.0781 - val_loss: 3.6740 - val_accuracy: 0.0582
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  157
# 4/4 [==============================] - 4s 1s/step - loss: 3.3771 - accuracy: 0.1562 - val_loss: 3.6613 - val_accuracy: 0.0655
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  158
# 4/4 [==============================] - 4s 1s/step - loss: 3.3290 - accuracy: 0.1484 - val_loss: 3.6595 - val_accuracy: 0.0714
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  159
# 4/4 [==============================] - 4s 1s/step - loss: 3.3047 - accuracy: 0.1484 - val_loss: 3.6873 - val_accuracy: 0.0635
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  160
# 4/4 [==============================] - 4s 1s/step - loss: 3.5475 - accuracy: 0.1172 - val_loss: 3.6841 - val_accuracy: 0.0562
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  161
# 4/4 [==============================] - 4s 1s/step - loss: 3.4508 - accuracy: 0.1250 - val_loss: 3.6175 - val_accuracy: 0.0635
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  162
# 4/4 [==============================] - 4s 1s/step - loss: 3.2436 - accuracy: 0.1562 - val_loss: 3.6118 - val_accuracy: 0.0642
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  163
# 4/4 [==============================] - 4s 1s/step - loss: 3.3745 - accuracy: 0.0859 - val_loss: 3.6126 - val_accuracy: 0.0608
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  164
# 4/4 [==============================] - 4s 1s/step - loss: 3.2797 - accuracy: 0.1016 - val_loss: 3.6228 - val_accuracy: 0.0615
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  165
# 4/4 [==============================] - 4s 1s/step - loss: 3.3567 - accuracy: 0.1484 - val_loss: 3.6343 - val_accuracy: 0.0648
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  166
# 4/4 [==============================] - 4s 1s/step - loss: 3.4437 - accuracy: 0.1484 - val_loss: 3.6452 - val_accuracy: 0.0661
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  167
# 4/4 [==============================] - 4s 1s/step - loss: 3.4309 - accuracy: 0.0938 - val_loss: 3.6388 - val_accuracy: 0.0708
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  168
# 4/4 [==============================] - 4s 1s/step - loss: 3.3773 - accuracy: 0.1406 - val_loss: 3.6222 - val_accuracy: 0.0747
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  169
# 4/4 [==============================] - 4s 1s/step - loss: 3.3492 - accuracy: 0.1250 - val_loss: 3.6329 - val_accuracy: 0.0635
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  170
# 4/4 [==============================] - 4s 1s/step - loss: 3.3424 - accuracy: 0.1953 - val_loss: 3.6491 - val_accuracy: 0.0688
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  171
# 4/4 [==============================] - 4s 1s/step - loss: 3.4372 - accuracy: 0.1172 - val_loss: 3.6291 - val_accuracy: 0.0721
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  172
# 4/4 [==============================] - 4s 1s/step - loss: 3.2682 - accuracy: 0.1328 - val_loss: 3.6187 - val_accuracy: 0.0747
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  173
# 4/4 [==============================] - 4s 1s/step - loss: 3.2875 - accuracy: 0.1328 - val_loss: 3.6367 - val_accuracy: 0.0734
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  174
# 4/4 [==============================] - 4s 1s/step - loss: 3.4344 - accuracy: 0.1016 - val_loss: 3.6428 - val_accuracy: 0.0741
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  175
# 4/4 [==============================] - 4s 1s/step - loss: 3.3644 - accuracy: 0.1484 - val_loss: 3.6428 - val_accuracy: 0.0761
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  176
# 4/4 [==============================] - 4s 1s/step - loss: 3.3871 - accuracy: 0.1250 - val_loss: 3.6401 - val_accuracy: 0.0694
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  177
# 4/4 [==============================] - 4s 1s/step - loss: 3.4691 - accuracy: 0.1016 - val_loss: 3.6513 - val_accuracy: 0.0608
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  178
# 4/4 [==============================] - 4s 1s/step - loss: 3.4549 - accuracy: 0.1172 - val_loss: 3.6423 - val_accuracy: 0.0589
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  179
# 4/4 [==============================] - 4s 1s/step - loss: 3.2918 - accuracy: 0.1719 - val_loss: 3.6416 - val_accuracy: 0.0562
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  180
# 4/4 [==============================] - 4s 1s/step - loss: 3.3644 - accuracy: 0.1406 - val_loss: 3.6231 - val_accuracy: 0.0569
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  181
# 4/4 [==============================] - 4s 1s/step - loss: 3.3297 - accuracy: 0.1562 - val_loss: 3.6266 - val_accuracy: 0.0655
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  182
# 4/4 [==============================] - 4s 1s/step - loss: 3.3179 - accuracy: 0.1562 - val_loss: 3.6289 - val_accuracy: 0.0675
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  183
# 4/4 [==============================] - 4s 1s/step - loss: 3.4042 - accuracy: 0.1250 - val_loss: 3.6433 - val_accuracy: 0.0741
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  184
# 4/4 [==============================] - 4s 1s/step - loss: 3.2619 - accuracy: 0.1484 - val_loss: 3.6472 - val_accuracy: 0.0701
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  185
# 4/4 [==============================] - 4s 1s/step - loss: 3.4363 - accuracy: 0.1641 - val_loss: 3.6386 - val_accuracy: 0.0668
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  186
# 4/4 [==============================] - 4s 1s/step - loss: 3.4081 - accuracy: 0.1250 - val_loss: 3.6307 - val_accuracy: 0.0767
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  187
# 4/4 [==============================] - 4s 1s/step - loss: 3.1776 - accuracy: 0.1406 - val_loss: 3.6286 - val_accuracy: 0.0761
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  188
# 4/4 [==============================] - 4s 1s/step - loss: 3.2612 - accuracy: 0.1562 - val_loss: 3.6270 - val_accuracy: 0.0767
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  189
# 4/4 [==============================] - 4s 1s/step - loss: 3.4904 - accuracy: 0.0938 - val_loss: 3.6310 - val_accuracy: 0.0767
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  190
# 4/4 [==============================] - 4s 1s/step - loss: 3.2990 - accuracy: 0.0859 - val_loss: 3.6295 - val_accuracy: 0.0728
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  191
# 4/4 [==============================] - 4s 1s/step - loss: 3.2173 - accuracy: 0.1172 - val_loss: 3.6596 - val_accuracy: 0.0741
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  192
# 4/4 [==============================] - 4s 1s/step - loss: 3.4968 - accuracy: 0.1016 - val_loss: 3.6615 - val_accuracy: 0.0741
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  193
# 4/4 [==============================] - 4s 1s/step - loss: 3.4543 - accuracy: 0.1016 - val_loss: 3.6451 - val_accuracy: 0.0747
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  194
# 4/4 [==============================] - 4s 1s/step - loss: 3.3739 - accuracy: 0.1250 - val_loss: 3.6834 - val_accuracy: 0.0661
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  195
# 4/4 [==============================] - 4s 1s/step - loss: 3.1800 - accuracy: 0.1875 - val_loss: 3.6685 - val_accuracy: 0.0675
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  196
# 4/4 [==============================] - 4s 1s/step - loss: 3.2863 - accuracy: 0.1328 - val_loss: 3.6553 - val_accuracy: 0.0642
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  197
# 4/4 [==============================] - 4s 1s/step - loss: 3.1791 - accuracy: 0.1797 - val_loss: 3.7011 - val_accuracy: 0.0569
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  198
# 4/4 [==============================] - 4s 1s/step - loss: 3.3399 - accuracy: 0.1250 - val_loss: 3.7305 - val_accuracy: 0.0608
#
# Epoch 00001: val_loss did not improve from 3.59900
# epoch  199
# 4/4 [==============================] - 4s 1s/step - loss: 3.5263 - accuracy: 0.1406 - val_loss: 3.6344 - val_accuracy: 0.0734
#
# Epoch 00001: val_loss did not improve from 3.59900

# %% [markdown]
# ---

# %% [markdown]
# ##**5.4 Model Performance**
#
# We will assess the performance of the model by plotting the **validation set loss versus the training set loss**. If the performance of the training set improves too fast and diverges from the validation set, this is a sign of overfitting. Our objective is to prevent overfitting, thus making the model more robust to unseen data.

# %%
# plot training loss vs. validation loss over epochs
val_loss_change = []; loss_change = []
for i in range(0, epochs):
    val_loss_change.append(history.history['val_loss'][i])
    loss_change.append(history.history['loss'][i])

plt.plot(val_loss_change, label='val_loss')
plt.plot(loss_change, label='train_loss')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# We will also assess the performance of the model by plotting the **validation set accuracy versus the training set accuracy**.

# %%
# plot training loss vs. validation loss over epochs
val_accuracy_change = []; accuracy_change = []
for i in range(0, epochs):
    val_accuracy_change.append(history.history['val_accuracy'][i])
    accuracy_change.append(history.history['accuracy'][i])

plt.plot(val_accuracy_change, label='val_accuracy')
plt.plot(accuracy_change, label='train_accuracy')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# **Check the training set loss and accuracy.**

# %%
# loss and accuracy on training set
train_eval = age_model.evaluate(train_x, train_y, verbose=1 , return_dict=True)
train_eval
# Out:
# 111/111 [==============================] - 8s 67ms/step - loss: 3.1395 - accuracy: 0.1881
# {'accuracy': 0.18808510899543762, 'loss': 3.1394870281219482}

# %% [markdown]
# **Check the test set loss and accuracy.**

# %%
# loss and accuracy on test set
test_eval = age_model.evaluate(test_x, test_y, verbose=1 , return_dict=True)
test_eval
# Out:
# 48/48 [==============================] - 3s 61ms/step - loss: 3.5990 - accuracy: 0.0681
# {'accuracy': 0.06812169402837753, 'loss': 3.5989954471588135}

# %% [markdown]
# **Predictions on the test set.**

# %%
predictions = age_model.predict(test_x)

# %% [markdown]
# **The array of predictions need to be decoded into predicted ages.**

# %%
output_indexes = np.array([i for i in range(8, 81)])
apparent_predictions = np.sum(predictions * output_indexes, axis = 1)

# %% [markdown]
# **Let's take a look at the maximum, minimum and mean age predictions to ensure that our distribution of values is what we expected.**

# %%
prediction_list = []
for i in range(73):
  prediction_list.append((np.argmax(predictions[i] * output_indexes[i])+8))

print("Minumum Predicted Age:",min(prediction_list))
print("Maximum Predicted Age:",max(prediction_list))
print("Average Predicted Age:",np.mean(prediction_list))
# Out:
# Minumum Predicted Age: 8
# Maximum Predicted Age: 80
# Average Predicted Age: 45.3013698630137

# %% [markdown]
# **Mean Absolute Error**
#
# Compute the Mean Absolute Error (MAE) to see how far the predicted ages are from the actual ages on average. MAE is the primary performance metric of our project.

# %%
# compute mae
mae_sum = 0
errors = []
n = apparent_predictions.shape[0]
prediction_list = []
for i in range(n):
    prediction = apparent_predictions[i]
    actual = np.argmax(test_y[i]) + 8
    mae_sum += abs(actual  - prediction)

    prediction_list.append(int(apparent_predictions[i])) # create a prediction list to plot
    errors.append((np.argmax(test_y[i]) + 8) - apparent_predictions[i])

mae = mae_sum / n
print("mae: ",mae)
print("instances: ", n)
# Out:
# mae:  7.65525963119018
# instances:  1512

# %%
# visualize the actual vs predicted age error distribution 
positive_errors = [i for i in errors if i > 0]
negative_errors = [i for i in errors if i < 0]

fig, ax = plt.subplots(figsize=(5,5))
sns.set_theme(style="darkgrid")
sns.histplot(positive_errors, color='blue', alpha=.8)
sns.histplot(negative_errors, color='red', alpha=.8)
plt.title('Error Distribution')
plt.xlabel('Error');

# %%
# Let's assume a Gaussian distribution of the errors
errors_mean = np.mean(errors)
errors_std = np.std(errors)
positive_std   = np.mean(errors) + np.std(errors) 
positive_std2  = np.mean(errors) + np.std(errors)*2
positive_std3  = np.mean(errors) + np.std(errors)*3
negative_std   = np.mean(errors) - np.std(errors)
negative_std2  = np.mean(errors) - np.std(errors)*2
negative_std3  = np.mean(errors) - np.std(errors)*3

print("Errors: Mean:",errors_mean)
print("Errors: Standard Deviation:",errors_std)
print("Errors: 1 Positive Standard Deviation: ",positive_std)
print("Errors: 2 Positive Standard Deviation: ",positive_std2)
print("Errors: 3 Positive Standard Deviation: ",positive_std3)
print("Errors: 1 Negative Standard Deviation:",negative_std)
print("Errors: 2 Negative Standard Deviation:",negative_std2)
print("Errors: 3 Negative Standard Deviation:",negative_std3)
# Out:
# Errors: Mean: -0.5127970834061821
# Errors: Standard Deviation: 10.780623882597904
# Errors: 1 Positive Standard Deviation:  10.267826799191722
# Errors: 2 Positive Standard Deviation:  21.048450681789628
# Errors: 3 Positive Standard Deviation:  31.82907456438753
# Errors: 1 Negative Standard Deviation: -11.293420966004087
# Errors: 2 Negative Standard Deviation: -22.07404484860199
# Errors: 3 Negative Standard Deviation: -32.854668731199894

# %%
# 68, 95, 99.7 = "three-sigma rule" AKA empirical rule for normal distributions
print("~ 68%   prediction errors from",round(negative_std,2),'to',round(positive_std,2))
print("~ 95%   prediction errors from",round(negative_std2,2),'to',round(positive_std2,2))
print("~ 99.7% prediction errors from",round(negative_std3,2),'to',round(positive_std3,2))
# Out:
# ~ 68%   prediction errors from -11.29 to 10.27
# ~ 95%   prediction errors from -22.07 to 21.05
# ~ 99.7% prediction errors from -32.85 to 31.83

# %%
# # visualize the actual vs predicted age error distribution with standard deviations as x ticks

fig, ax = plt.subplots(figsize=(5,5))
sns.set_theme(style="darkgrid")
sns.histplot(positive_errors, color='blue', alpha=.8)
sns.histplot(negative_errors, color='red', alpha=.8)
plt.title('Error Distribution')
plt.xlabel('Error')
ticky = [negative_std3, negative_std2, negative_std, errors_mean, positive_std, positive_std2, positive_std3]
tacky = ['-3σ','-2σ','-1σ','|','1σ','2σ','3σ']
plt.xticks(ticky, tacky);

# %% [markdown]
# **Mean Absolute Percentage Error**
#
# Compute the Mean Absolute Percentage Error (MAPE) to see how far the predicted ages are from the actual ages on average as a percentage.

# %%
# create list 'test_y_age'  of the actual age labels
test_y_age = np.argmax(test_y, axis=1)

# ADD 8 to the test_y labels. 8 was subtracted for one-hot categorical encoding
test_y_age = test_y_age + 8

# %%
# calculate MAPE
mape_sum = 0
n = apparent_predictions.shape[0]
for i in range(n): 
  mape_sum += (abs((test_y_age[i]) - (apparent_predictions[i]))/(test_y_age[i]))
mape = (mape_sum/n) 

print(mape)
print('MAPE:',(round(mape*100,2)),"%")
# Out:
# 0.26266383270860244
# MAPE: 26.27 %

# %% [markdown]
# ---

# %% [markdown]
# ##**5.5 Performance Visualization**
#
# Let's create data visualizations to compare the predicted ages with the actual ages. We will create a few to survey which data visualization is the most useful for analysis.

# %%
# plot a scatterplot with a 'perfect prediction' line
sns.set_theme(style="darkgrid")
fig, ax = plt.subplots(figsize=(10,10))
sns.scatterplot(test_y_age, apparent_predictions)
ax.plot([y.min(), y.max()], [y.min(), y.max()], 'k--', lw=3)
ax.set_xlabel('Actual Age')
ax.set_ylabel('Predicted Age');
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **Observation:** Above, we can see the 'perfect prediction' dotted line and get a general sense of the error pattern in the system. Generally, there is a positive correlation between actual age and predicted age. We can also see some predictions far from the ideal line.

# %%
# jointplot - scatterplot with histogram
sns.jointplot(test_y_age, apparent_predictions)
ax.set_xlabel('Actual Age')
ax.set_ylabel('Predicted Age');
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **Correlation**
#
# Check Pearson Correlation Coefficient between predicted ages and actual ages.

# %%
# corr(test_y_age, apparent_predictions)
np.corrcoef(test_y_age, apparent_predictions)
# Out:
# array([[1.        , 0.85894874],
#        [0.85894874, 1.        ]])

# %% [markdown]
# **Confusion Matrix**
#
# We will create and plot a Confusion Matrix to visualize prediction accuracy in a grid.

# %%
# confusion_matrix
from sklearn.metrics import confusion_matrix
import itertools
sns.set_theme(style='dark')
# prediction_list = np.array(prediction_list) + 8
conf_mat1 = confusion_matrix(test_y_age, prediction_list)

# %%
# plot the confusion matrix 
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion Matrix', export_as='confusion_matrix', cmap=plt.cm.Blues):
    plt.imshow(cm, cmap=cmap, interpolation='nearest')
    plt.title(title, fontsize=22)
    plt.colorbar()
    a_list = list(range(73))
    b_list = [8,'',10,'','','','',15,'','','','',20,'','','','',25,'','','','',30,'','','','',35,'','','','',40,'','','','',\
                   45,'','','','',50,'','','','',55,'','','','',60,'','','','',65,'','','','',70,'','','','',75 ,'','','','',80]
    plt.xticks(a_list, b_list, fontsize=12)
    plt.yticks(a_list, b_list, fontsize=12)

    plt.tight_layout()
    plt.ylabel('Predicted Age', fontsize=18)
    plt.xlabel('Actual Age', fontsize=18)
    plt.savefig('/content/drive/MyDrive/YOUNGER/conf_mat1.png');

# %%
plt.figure(figsize=(10,10))
plot_confusion_matrix(conf_mat1, list(range(73)), normalize=False,
                      title="Confusion Matrix: Age Prediction, CNN Model 1")
plt.show()

# %% [markdown]
# **Observation:**
# Again, we can see the correlation trend forming a linear shape. Perfect predictions would form a dark blue line from top-left to bottom-right. The predictions are far from perfect.
#
# **Best Predictions, Decent Predicitions, Poor Predictions**
#
# Clearly, the predictor predicts better at certain ages than other ages.
#
# The predictor is most accurate at ages: 8, 9, 11-14, 16 and 73.
#
#
# The predictor is somewhat accurate at ages: 14, 17, 25, 30, 31, 34, 36, 39, 40, 42, 45, 46, 49, 53, 56, 58, 63, 67, 70, 72, 73.
#
# The predictor predicts poorly at ages: 35, 43, 48, and 65.

# %% [markdown]
# ---

# %% [markdown]
# ##**5.6 Unseen Data Test**
#
# We will create a sequence to predict the ages of new images loaded through Google Drive and also images from on the Internet.
#
# We can imagine this being the "app" where a user inputs their photo and the app returns an age prediction. This is the practical application of the predictor.
#
# **There are 2 predictions.** Prediction 1 is the highest probability prediction and Prediction 2 is the average of the top 5 highest probability predictions.
#
# "Actual Ages" are based on the date the images were captured verified by cross-checking Getty Images for the celebrities.

# %%
# image preprocessing
def loadImage(filepath):
    test_img = image.load_img(filepath, target_size=(224, 224))
    test_img = image.img_to_array(test_img)
    test_img = np.expand_dims(test_img, axis = 0)
    test_img /= 255
    return test_img

# %%
# predictor function using the model created above
from keras.preprocessing import image
sns.set_theme(style='dark')

def image_age(photo):
  prediction2 = age_model.predict(loadImage(photo))
  img = image.load_img(photo)#, target_size=(224, 224))
  plt.xticks([], []), ax.set_xticks([]), plt.yticks([], []), ax.set_yticks([]) # clear x & y ticks
  plt.imshow(img)   # display image
  plt.show()
  
  # print("Predicted Age: ", (np.argmax(prediction))+8)
  apparent_age = np.round(np.sum(prediction2 * output_indexes, axis=1))
  print(" Predicted Age: ", int(apparent_age[0]))
  print(" Average Top 5: ",round(np.mean(np.argsort(prediction2[0])[-5:])+8))
  print(" ------------------")

# %%
# visualize probabilites of each age class
def viz_prob(pic):
  prediction_1 = age_model.predict(loadImage(pic))
  y_pos = np.arange(73)+8
  plt.bar(y_pos, prediction_1[0], align='center', alpha=0.8)
  plt.ylabel('predicted probability')
  plt.xlabel('age')
  plt.title('Age Prediction Probabilities')
  plt.show()

# %% [markdown]
# **Load New Image, Predict Age, Visualize Probabilites**

# %%
# insert image (of me) from Google Drive by path
picture1 = "/content/drive/MyDrive/YOUNGER/prem_linked.jpg"
image_age(picture1)
print(' Actual Age:     35')
viz_prob(picture1)
# Out:
#  Predicted Age:  38
#  Average Top 5:  36
#  ------------------
#  Actual Age:     35

# %%
picture2 = '/content/drive/MyDrive/YOUNGER/harrison_ford_70.jpg'
image_age(picture2)
print(' Actual Age:     70')
viz_prob(picture2)
# Out:
#  Predicted Age:  70
#  Average Top 5:  73
#  ------------------
#  Actual Age:     70

# %%
# create a web image upload & predict sequence
from PIL import Image
import requests

def web_age(url):  
  web_photo = Image.open(requests.get(url, stream=True).raw).save("web_photo.jpg")
  picture1 = "/content/web_photo.jpg"
  image_age(picture1)
  # viz_prob(picture1)

# %%
url = "https://media.allure.com/photos/5e8359941cb813000841fb8b/3:2/w_3000,h_2000,c_limit/celine%20dion.jpg"
web_age(url)
print(' Actual Age:     52')
# Out:
#  Predicted Age:  63
#  Average Top 5:  65
#  ------------------
#  Actual Age:     52

# %%
url = 'https://assets.vogue.com/photos/5e6f950f5530ac0009b932fb/1:1/w_3538,h_3538,c_limit/GettyImages-1205201930.jpg'
web_age(url)
print(' Actual Age:     63')
# Out:
#  Predicted Age:  62
#  Average Top 5:  60
#  ------------------
#  Actual Age:     63

# %%
url = 'https://media.gettyimages.com/photos/tom-hanks-attends-the-92nd-annual-academy-awards-at-hollywood-and-on-picture-id1205142068?s=2048x2048'
web_age(url)
print(' Actual Age:     63')
# Out:
#  Predicted Age:  65
#  Average Top 5:  71
#  ------------------
#  Actual Age:     63

# %% [markdown]
# The prediction is better for the image that is tightly cropped. The predictor was trained on images with a specific 40% margin, tightly cropped. We can expect that the predictor would perform better on images similar to the training set.
#
# One possible method to improve performance on unseen data is to have the system pre-process new images by cropping them with the correct margin and image size.

# %%
url = 'https://static.wikia.nocookie.net/euphoria-hbo/images/5/5c/Zendaya.jpg/revision/latest?cb=20190601162350'
web_age(url)
print(' Actual Age:     20')
# Out:
#  Predicted Age:  22
#  Average Top 5:  22
#  ------------------
#  Actual Age:     20

# %%
url = 'https://media.gettyimages.com/photos/zendaya-attends-the-rei-kawakubocomme-des-garcons-art-of-the-costume-picture-id675901048?s=2048x2048'
web_age(url)
print(' Actual Age:     20')
# Out:
#  Predicted Age:  39
#  Average Top 5:  14
#  ------------------
#  Actual Age:     20

# %% [markdown]
# Above, the same person, Zendaya, at the same age is predicted well, and then predicted poorly. Perhaps the unique hair feature is being read as wrinkles. Perhaps frizzy hair is associated with older people.

# %%
url = 'https://i.guim.co.uk/img/media/7f2b972fa41cd4d26a3620cea335aad33cde6c32/0_127_3500_2101/master/3500.jpg?width=445&quality=45&auto=format&fit=max&dpr=2&s=02571424bc9abc13340589ef47eb7b0b'
web_age(url)
print(' Actual Age:     34')
# Out:
#  Predicted Age:  43
#  Average Top 5:  43
#  ------------------
#  Actual Age:     34

# %%
url = 'https://static.wikia.nocookie.net/harrypotter/images/9/97/Harry_Potter.jpg/revision/latest?cb=20140603201724'
web_age(url)
print(' Actual Age:     20')
# Out:
#  Predicted Age:  27
#  Average Top 5:  17
#  ------------------
#  Actual Age:     20

# %%
url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRed4B_N95FjRE0a-2sn3OEXAjc0SkMkWeJTQ&usqp=CAU'
web_age(url)
print(' Actual Age:     48')
# Out:
#  Predicted Age:  48
#  Average Top 5:  49
#  ------------------
#  Actual Age:     48

# %% [markdown]
# ---

# %% [markdown]
# # **VI. SUMMARY**

# %% [markdown]
# Well, that was a lot. Let's take a look at what this notebook covers.
#
# **Preprocessing**
#
# During preprocessing, we loaded and prepared the data for machine learning by one-hot encoding the target classes. We scaled the pixel values from 0-255 to 0-1. We also split the data into training and testing subsets.
#
# **Modeling**
#
# Onward to modeling, we used a proven model arcitecture with pretrained weights for the first layers to expedite our learning. By using transfer learning we were able to use the existing model weights that have been previously trained on a massive 2.6 million image dataset. We froze the early layers and focuses on training the later layers in the model. Next we trained the model, observed results of the training, and reset the batchsize and the number of epochs to achieve a reasonable learning rate without overfitting.
#
# **Metrics**
#
# Our primary model performance metric is validation loss. We created our model to train to minimize validation loss and save the best weights progressively. We eventually got down to a reasonable validation loss for this project.
#
# Our primary overall metric is Mean Absolute Error (MAE). We want to minimize how far our predicted are from the actual ages. So far our MAE is still far from ideal. Training on a lot more data will help.
#
# **Visualizations**
#
# We created a confusion matrix, a scatterplot and a jointplot to get a sense of how well the model is predicting. Overall, the general trend is positive but there is room for improvement.
#
# **Unseen Data**
#
# We created a small program to predict the ages for new images from Google Drive and from the Internet. The results were encouraging.

# %% [markdown]
# ---

# %%
# one for the road
url = 'https://imagesvc.meredithcorp.io/v3/mm/image?q=85&c=sc&poi=face&w=1200&h=1600&url=https%3A%2F%2Fstatic.onecms.io%2Fwp-content%2Fuploads%2Fsites%2F20%2F2019%2F05%2Fkim-beauty.jpg'
web_age(url)
print(' Actual Age:     37')
# Out:
#  Predicted Age:  34
#  Average Top 5:  26
#  ------------------
#  Actual Age:     37

# %% [markdown]
# ---

# %% [markdown]
# # **VII. REFERENCES**

# %% [markdown]
# 1.   https://data.vision.ee.ethz.ch/cvl/rrothe/imdb-wiki/
# 2.   https://data.vision.ee.ethz.ch/cvl/publications/papers/proceedings/eth_biwi_01229.pdf
# 3. https://sefiks.com/2019/02/13/apparent-age-and-gender-prediction-in-keras/
# 4. https://www.researchgate.net/publication/265125544_Face_Detection_without_Bells_and_Whistles
# 5. https://github.com/yu4u/age-gender-estimation
# 6. https://www.robots.ox.ac.uk/~vgg/publications/2015/Parkhi15/parkhi15.pdf
# 7. https://link.springer.com/chapter/10.1007/978-3-319-10593-2_47
#
#
# ---

# %% [markdown]
# # **VIII. APPENDIX**

# %% [markdown]
# **Model Summary**
#
# [VGG-Face Model](https://https://www.robots.ox.ac.uk/~vgg/publications/2015/Parkhi15/parkhi15.pdf) was the basis for our model. We used the VGG-Face structure and trained on the last 4 custom layers.

# %%
age_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential_input (InputLayer [(None, 224, 224, 3)]     0
# _________________________________________________________________
# sequential (Sequential)      (None, 224, 224, 3)       0
# _________________________________________________________________
# zero_padding2d (ZeroPadding2 (None, 226, 226, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 224, 224, 64)      1792
# _________________________________________________________________
# zero_padding2d_1 (ZeroPaddin (None, 226, 226, 64)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 224, 224, 64)      36928
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 64)      0
# _________________________________________________________________
# zero_padding2d_2 (ZeroPaddin (None, 114, 114, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 112, 112, 128)     73856
# _________________________________________________________________
# zero_padding2d_3 (ZeroPaddin (None, 114, 114, 128)     0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 112, 112, 128)     147584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 128)       0
# _________________________________________________________________
# zero_padding2d_4 (ZeroPaddin (None, 58, 58, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 56, 56, 256)       295168
# _________________________________________________________________
# zero_padding2d_5 (ZeroPaddin (None, 58, 58, 256)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 56, 56, 256)       590080
# _________________________________________________________________
# zero_padding2d_6 (ZeroPaddin (None, 58, 58, 256)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 56, 56, 256)       590080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 28, 28, 256)       0
# _________________________________________________________________
# zero_padding2d_7 (ZeroPaddin (None, 30, 30, 256)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 28, 28, 512)       1180160
# _________________________________________________________________
# zero_padding2d_8 (ZeroPaddin (None, 30, 30, 512)       0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 28, 28, 512)       2359808
# _________________________________________________________________
# zero_padding2d_9 (ZeroPaddin (None, 30, 30, 512)       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 28, 28, 512)       2359808
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 512)       0
# _________________________________________________________________
# zero_padding2d_10 (ZeroPaddi (None, 16, 16, 512)       0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# zero_padding2d_11 (ZeroPaddi (None, 16, 16, 512)       0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# zero_padding2d_12 (ZeroPaddi (None, 16, 16, 512)       0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 7, 7, 512)         0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 1, 1, 4096)        102764544
# _________________________________________________________________
# dropout (Dropout)            (None, 1, 1, 4096)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 1, 1, 4096)        16781312
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1, 1, 4096)        0
# _________________________________________________________________
# predictions (Conv2D)         (None, 1, 1, 73)          299081
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 73)                0
# _________________________________________________________________
# activation_1 (Activation)    (None, 73)                0
# =================================================================
# Total params: 134,559,625
# Trainable params: 119,844,937
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %% [markdown]
# ---

# %% [markdown]
# **TensorBoard**
# TensorBoard visualization for experimentation.

# %%
# # !kill 380
# %tensorboard --logdir logs/fit

# %%
# !tensorboard dev upload \
#   --logdir logs/fit \
#   --name "My latest experiment" \
#   --description "Simple comparison of hyperparameters" \
#   --one_shot

# %% [markdown]
# [TensorBoard for this Notebook](hhttps://tensorboard.dev/experiment/VsomWP3YQsWuOFglmW7dnw/#graphs&run=20210518-022919%2Ftrain)

# %% [markdown]
# ---
